# %%
d={"accno":[101,102,103,104,105,106],"name":["harshit","mayank","aryan","deepak","rohit","manish"],"Balance":[1000,2000,5000,30000,10000,40000],'password':['harshit@123','mayank@123',""]}
# to print details
a=int(input("enter account no : "))
l=d["accno"]
i=l.index(a)
print("               |accountno|name    |Balance|  ")
print("your details : |{}      |{} |{}   |".format(d["accno"][i],d["name"][i],d["Balance"][i]))
n=int(input("press 1 for Deposit and 2 for withdrawl : "))
if n!=1 and n!=2 :
    print("invalid input !!")
elif n==1 :
    p=int(input("enter amount to deposit in dollars : "))
    d["Balance"][i]+=p
    print("updated balance : ",d["Balance"][i] ,'$') 
    print("your details : |{}      |{} |{}   |".format(d["accno"][i],d["name"][i],d["Balance"][i]))
else :
    p=int(input("enter amount to withdrawl dollars : "))
    if p> d["Balance"][i] :
        print("Sorry insufficient balance!!")
        print("your balance : ",d["Balance"][i] ,'$')
        
    d["Balance"][i]-=p
    print("updated balance : ",d["Balance"][i] ,'$') 
    print("your details : |{}      |{} |{}   |".format(d["accno"][i],d["name"][i],d["Balance"][i]))
# Out:
# enter account no : 102
#                |accountno|name    |Balance|
# your details : |102      |mayank |2000   |

# %%
#bank using jason and log

bank = { 
        'user' : [ 'ram', 'sam','vijay' ],
        'acc' : [ 1001, 1002, 1003 ],
        'password' : [ 'grras@123', 'something', 'redhat'],
        'balance' : [ 10000.23, 20000.45, 124322.234]
        }
import json
import time
from getpass import getpass

f=open("C:\\Users\\dell\\Desktop\\rec.txt","w")
f.writable()
json.dump(bank,f)
f.close()

f=open("C:\\Users\\dell\\Desktop\\rec.txt",)
d=json.load(f)
for key,value in d.items():
    print("records {} : {} : ".format(key,value))
# Out:
# records user : ['ram', 'sam', 'vijay'] :
# records acc : [1001, 1002, 1003] :
# records password : ['grras@123', 'something', 'redhat'] :
# records balance : [10000.23, 20000.45, 124322.234] :

# %%
# banking part

admin = 'root'
admin_password = 'red'
f=open("C:\\Users\\dell\\Desktop\\log.txt","w")
f.close()
while True :
    
    print(time,"\n")
    print("\n\n")
    print("*"*50)
    print("Welcome to Python Bank")
    print("*"*50)
    f=open("C:\\Users\\dell\\Desktop\\log.txt","a")
    s="application run by user : {}\n".format(time.ctime())
    f.write(s)
    f.close()
    print("\n\n1. Login \n2. Signup \n3. Admin \n4. Exit")
    ch = int(input("Your Choice : "))
    
    if ch == 1 :
        print("\n\n")
        uacc = int(input("Acc Number : "))
        if uacc in bank['acc'] :
            upass = getpass("Password : ")
            index = bank['acc'].index(uacc)
            if upass == bank['password'][index]:
                f=open("C:\\Users\\dell\\Desktop\\log.txt","a")
                s=" {} login succesfull : {}\n".format(uacc,time.ctime())
                f.write(s)
                f.close()
                while True :
                    print("\n\n1. Deposit\n2. withdrawal\n3. Check Balance\n4. Change Password \n5. Logout")
                    ch = int(input("Choice : "))
                    if ch == 1 :
                        p=int(input("enter amount to deposit in rupees : "))
                        bank['balance'][index]+=p
                        f=open("C:\\Users\\dell\\Desktop\\rec.txt","w")
                        json.dump(bank,f)
                        f.close()
                        print("\nyour udated balance", bank['balance'][index])
                        f=open("C:\\Users\\dell\\Desktop\\log.txt","a")
                        s=" {} balance updated : {}\n".format(uacc,time.ctime())
                        f.write(s)
                        f.close()
                    elif ch == 2 :
                        z=int(input("\nenter amount to withrawal in rupees : "))
                        if z>bank['balance'][index]:
                            print('\ninsufficient balance')
                        else :
                            bank['balance'][index]-=p
                            f=open("C:\\Users\\dell\\Desktop\\rec.txt","w")
                            json.dump(bank,f)
                            f.close()
                            print("\nyour udated balance : ", bank['balance'][index])
                            f=open("C:\\Users\\dell\\Desktop\\log.txt","a")
                            s=" {} balance updated : {}\n".format(uacc,time.ctime())
                            f.write(s)
                            f.close()
                    
                    elif ch == 3 :
                        print("your udated balance : ",bank['balance'][index])
                        f=open("C:\\Users\\dell\\Desktop\\rec.txt","a")
                        s=" {} balance updated : {}\n".format(uacc,time.ctime())
                        f.write(s)
                        f.close()
                        
                        
                    elif ch == 4 :
                        
                        upass=getpass("new password")
                        upass1=getpass("verify passwoord")
                        if upass==upass1:
                            bank['password'][index]=upass
                            f=open("C:\\Users\\dell\\Desktop\\rec.txt","w")
                            json.dump(bank,f)
                            f.close()
                        
                        
                    elif ch == 5 :
                        print("\nLogging you out.....\n")
                        f=open("C:\\Users\\dell\\Desktop\\log.txt","a")
                        s=" {} user logout : {}\n".format(uacc,time.ctime())
                        f.write(s)
                        f.close()
                        break
                    else :
                        print("\n\nInvalid Choice ")
                        print("Try Again")
            else :
                print("\n\nInvalid Password\n\nTry Again")
                f=open("C:\\Users\\dell\\Desktop\\rec.txt","a")
                s=" {} login failed : {}\n".format(uacc,time.ctime())
                f.write(s)
                f.close()
            
        else :
            print("\n\nNo such Account Exists \nYou should signup\n\n")
    elif ch == 2 :
        acc = bank['acc'][-1] + 1
        name = input("Username : ")
        bal = float(input("Initial Blance : "))
        password = getpass("Set Password : ")
        bank['user'].append(name)
        bank['acc'].append(acc)
        bank['password'].append(password)
        bank['balance'].append(bal)
        f=open("C:\\Users\\dell\\Desktop\\rec.txt","w")
        json.dump(bank,f)
        f.close()
        
        print("\nAccount Sucessfully Created")
        f=open("C:\\Users\\dell\\Desktop\\rec.txt","a")
        s="new account created : {}  : {}\n".format(acc,time.ctime())
        f.write(s)
        f.close()
        print("Note down your account num :  {}".format(acc))
        print("Now you can login\n")
    elif ch == 3 :
        username = input("\nEnter name : ").strip().lower()
        password = input("\nenter password")
        if username == admin :
            if password == admin_password :
                print("admin access succcessful")
                f=open("C:\\Users\\dell\\Desktop\\log.txt","a")
                s="admin login : {}\n".format(time.ctime())
                f.write(s)
                f.close()
                for key,value in bank.items():
                    print("{}={}".format(key,value))
            else :
                print("\nInvalid password \nTry Again")
        else :
             print("\nThis user is not an admin.")
    elif ch == 4 :
        ch = input("\n\nDo really want to exit ? (y/n) : ").strip().lower()
        if ch == 'y' or ch == 'yes' :      
            print("\nThanks for using our services ")
            f=open("C:\\Users\\dell\\Desktop\\rec.txt","a")
            s=" {} user logout : {}\n".format(uacc,time.ctime())
            f.write(s)
            f.close()
            
            break
    else :
        print("\nInvalidChoice\nTry again")
# Out:
# <module 'time' (built-in)>
#
#
#
#
# **************************************************
# Welcome to Python Bank
# **************************************************
#
#
# 1. Login
# 2. Signup
# 3. Admin
# 4. Exit
# Your Choice : 3
#
# Enter name : root
#
# enter passwordred
# admin access succcessful
# user=['ram', 'sam', 'vijay']
# acc=[1001, 1002, 1003]
# password=['grras@123', 'something', 'redhat']
# balance=[10000.23, 20000.45, 124322.234]
# <module 'time' (built-in)>
#
#
#
#
# **************************************************
# Welcome to Python Bank
# **************************************************
#
#
# 1. Login
# 2. Signup
# 3. Admin
# 4. Exit

# %%
bank = { 
        'user' : [ 'ram', 'sam','vijay' ],
        'acc' : [ 1001, 1002, 1003 ],
        'password' : [ 'grras@123', 'something', 'redhat'],
        'balance' : [ 10000.23, 20000.45, 124322.234]
        }
import json
import time
from getpass import getpass




############ Function definitions  ###############

def bank_Json():
    f=open("C:\\Users\\dell\\Desktop\\rec.txt","w")
    json.dump(bank,f)
    f.close()


    
def bank_Json_load():
    f=open("C:\\Users\\dell\\Desktop\\rec.txt",)
    d=json.load(f)
    for key,value in d.items():
        print("records {} : {} : ".format(key,value))
    
def bank_Log():
    f=open("C:\\Users\\dell\\Desktop\\log.txt","a")

def deposit():
    p=int(input("enter amount to deposit in rupees : "))
    bank['balance'][index]+=p
    bank_Json()
    print("\nyour udated balance", bank['balance'][index])
    bank_Log()
    s=" {} balance updated : {}\n".format(uacc,time.ctime())
    f.write(s)
    f.close()    
    
def withdrawl():
    z=int(input("\nenter amount to withrawal in rupees : "))
    if z>bank['balance'][index]:
        print('\ninsufficient balance')
    else :
        bank['balance'][index]-=p
        bank_Json()
        print("\nyour udated balance : ", bank['balance'][index])
        bank_Log()
        s=" {} balance updated : {}\n".format(uacc,time.ctime())
        f.write(s)
        f.close()

def checkbal():
    print("your udated balance : ",bank['balance'][index])
    bank_Log()
    s=" {} balance updated : {}\n".format(uacc,time.ctime())
    f.write(s)
    f.close()                        

def chpassword():

    upass=getpass("new password")
    upass1=getpass("verify passwoord")
    if upass==upass1:
        bank['password'][index]=upass
        bank_Json()
def logout():
    print("\nLogging you out.....\n")
    bank_Log()
    s=" {} user logout : {}\n".format(uacc,time.ctime())
    f.write(s)
    f.close()

    
    

def login():
    uacc = int(input("Acc Number : "))
    if uacc in bank['acc'] :
        upass = getpass("Password : ")
        index = bank['acc'].index(uacc)
        if upass == bank['password'][index]:
            bank_Log()
            s=" {} login succesfull : {}\n".format(uacc,time.ctime())
            f.write(s)
            f.close()
            while True :
                print("\n\n1. Deposit\n2. withdrawal\n3. Check Balance\n4. Change Password \n5. Logout")
                ch = int(input("Choice : "))
                if ch == 1 :
                    deposit()

                elif ch == 2 :
                    withdrawl()

                elif ch == 3 :
                    checkbal()


                elif ch == 4 :
                    chpassword()

                elif ch == 5 :
                    logout()

                else :
                    print("\n\nInvalid Choice ")
                    print("Try Again")
        else :
            print("\n\nInvalid Password\n\nTry Again")
            bank_Log()
            s=" {} login failed : {}\n".format(uacc,time.ctime())
            f.write(s)
            f.close()
    else :
        print("\n\nNo such Account Exists \nYou should signup\n\n")


        
        
        
def signup():
    acc = bank['acc'][-1] + 1
    name = input("Username : ")
    bal = float(input("Initial Blance : "))
    password = getpass("Set Password : ")
    bank['user'].append(name)
    bank['acc'].append(acc)
    bank['password'].append(password)
    bank['balance'].append(bal)
    bank_Json()

    print("\nAccount Sucessfully Created")
    bank_Log()
    s="new account created : {}  : {}\n".format(acc,time.ctime())
    f.write(s)
    f.close()
    print("Note down your account num :  {}".format(acc))
    print("Now you can login\n")
    
def admin():
    username = input("\nEnter name : ").strip().lower()
    password = input("\nenter password")
    if username == admin :
        if password == admin_password :
            print("admin access succcessful")
            f=open("C:\\Users\\dell\\Desktop\\log.txt","a")
            s="admin login : {}\n".format(time.ctime())
            f.write(s)
            f.close()
            for key,value in bank.items():
                print("{}={}".format(key,value))
        else :
            print("\nInvalid password \nTry Again")
    else :
        print("\nThis user is not an admin.")

def Exit():
    ch = input("\n\nDo really want to exit ? (y/n) : ").strip().lower()
    if ch == 'y' or ch == 'yes' :      
        print("\nThanks for using our services ")
        bank_Log()
        s=" {} user logout : {}\n".format(uacc,time.ctime())
        f.write(s)
        f.close()
        return True
       
      
   

  ####### Bank System  #######
    
    
admin = 'root'
admin_password = 'red'
f=open("C:\\Users\\dell\\Desktop\\log.txt","w")
f.close()
while True :
    
    print(time,"\n")
    print("\n\n")
    print("*"*50)
    print("Welcome to Python Bank")
    print("*"*50)
    bank_Log()
    s="application run by user : {}\n".format(time.ctime())
    f.write(s)
    f.close()
    
    print("\n\n1. Login \n2. Signup \n3. Admin \n4. Exit")
    ch = int(input("Your Choice : "))
    if ch == 1 :
        print("\n\n")
        login()
    
    elif ch == 2 :
        signup()
    
    
    elif ch == 3 :
        admin()
    
    elif ch == 4 :
        exit()
        break
        
        
    else :
        print("\nInvalidChoice\nTry again")
# Out:
# <module 'time' (built-in)>
#
#
#
#
# **************************************************
# Welcome to Python Bank
# **************************************************
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-c069f8bdeeba> in <module>()
#     187     bank_Log()
#     188     s="application run by user : {}\n".format(time.ctime())
# --> 189     f.write(s)
#     190     f.close()
#     191
#
# ValueError: I/O operation on closed file.
